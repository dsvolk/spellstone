# %% [markdown]
# # ObsidianTools examples

# %%
import sys 
sys.path.append('..')

import os
from dotenv import load_dotenv
load_dotenv('.env', override=True)

import obsidiantools.api as otools
from obsidiantools.md_utils import get_tags
from pprint import pprint
import markdown
import frontmatter

# %%
VAULT_DIR = os.environ.get('VAULT_DIR')
VAULT_DIR
# Out:
# '/Users/dvolk/repo/cobrain/vault'

# %%
class Section:
    def __init__(self, title, level):
        self.title = title
        self.level = level
        self.content = []
        self.subsections = []

    def add_content(self, content):
        self.content.append(content)

    def add_subsection(self, subsection):
        self.subsections.append(subsection)

    def __repr__(self):
        return f"Section(title={self.title}, level={self.level}, content={self.content}, subsections={self.subsections})"

# %%
def parse_markdown(file_path):
    root = Section(title="root", level=0)
    current_section = root

    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line.startswith('#'):
                # Count the level of the section
                level = len(line.split(' ')[0])
                title = line[level+1:].strip()

                # Create a new section
                new_section = Section(title=title, level=level)

                # Find the correct parent for the new section
                while current_section.level >= level:
                    current_section = current_section.parent
                current_section.add_subsection(new_section)
                
                # Update current section
                new_section.parent = current_section
                current_section = new_section
            else:
                # Add line to the content of the current section
                current_section.add_content(line)

    return root

# %%
MAX_FILES = 10

def load_markdown_files(directory):
    file_count = 0
    for filename in os.listdir(directory):
        if filename.endswith(".md"):
            print(filename)
            filepath = os.path.join(directory, filename)
            # tags = get_tags(filepath, show_nested=True)
            # print(f"Tags: {tags}") if tags else None

            with open(filepath) as f:
                metadata, content = frontmatter.parse(f.read())
            
            print(f"Frontmatter: {metadata}")

            sections = parse_markdown(filepath)

            yield filepath, metadata.get("tags", []), sections

            file_count += 1
            if file_count >= MAX_FILES:
                break

            # with open(filepath, 'r', encoding='utf-8') as file:
            #     text = file.read()
            #     content = markdown.markdown(text)
            #     metadata = content.metadata if hasattr(content, 'metadata') else {}
            #     tags = metadata.get('tags', '').split(', ') if 'tags' in metadata else []
            #     yield content, tags

# %%
for content, tags, sections in load_markdown_files(VAULT_DIR + '/notes'):
    print(content)
    print(tags)
    print(sections)
    print()
    print('---')
# Out:
# Lessons on ML Platforms — from Netflix, DoorDash, Spotify, and more _ by Ernest Chan _ May, 2021 _ Towards Data Science.md
# Frontmatter: {'aliases': None, 'created': datetime.date(2021, 6, 3), 'modified': datetime.date(2021, 6, 3), 'tags': ['DataScience', 'Machine-Learning'], 'evernote': '@Archive', 'url': 'https://towardsdatascience.com/lessons-on-ml-platforms-from-netflix-doordash-spotify-and-more-f455400115c7'}
# /Users/dvolk/repo/cobrain/vault/notes/Lessons on ML Platforms — from Netflix, DoorDash, Spotify, and more _ by Ernest Chan _ May, 2021 _ Towards Data Science.md
# ['DataScience', 'Machine-Learning']
# Section(title=root, level=0, content=['---', 'aliases:', 'created: 2021-06-03', 'modified: 2021-06-03', 'tags:', '- DataScience', '- Machine-Learning', 'evernote: "@Archive"', 'url: https://towardsdatascience.com/lessons-on-ml-platforms-from-netflix-doordash-spotify-and-more-f455400115c7', '---'], subsections=[Section(title=Lessons on ML Platforms — from Netflix, DoorDash, Spotify, and more | by Ernest Chan | May, 2021 | Towards Data Science, level=1, content=['[[MLOps]]'], subsections=[Section(title=[Notes from Industry](https://towardsdatascience.com/tagged/notes-from-industry), level=2, content=[''], subsections=[])]), Section(title=Lessons on ML Platforms — from Netflix, DoorDash, Spotify, and more, level=1, content=['', '[![[1_e0kOhhsKuz075oLHDY-JOQ.jpeg]]](https://ernestklchan.medium.com/?source=post_page-----f455400115c7--------------------------------)', '', '[Ernest Chan](https://ernestklchan.medium.com/?source=post_page-----f455400115c7--------------------------------)', '', '[May 12·12 min read](https://towardsdatascience.com/lessons-on-ml-platforms-from-netflix-doordash-spotify-and-more-f455400115c7?source=post_page-----f455400115c7--------------------------------)', '', 'Your data scientists produce wonderful models, but they can only deliver value once the models are integrated into your production systems. How do you make it easy for the data scientists to _repeatedly_ deliver value? What do you build, what do you buy, and what tools do you need to solve your organization’s problems specifically?', '', 'Many companies who do ML well have invested in ML platforms to enable data scientists to deliver value quicker. These platforms solve problems common to many ML tasks and empower data scientists to focus on where they can uniquely add value. The goal of platforms is aptly summarized by this diagram from the Metaflow project.', '', '![[0_6qUycUMFDSLASLFs.png]]', '![[0_6qUycUMFDSLASLFs.1.png]]', '', 'Source: https://docs.metaflow.org/introduction/what-is-metaflow', '', 'We can learn from the ML platforms of successful tech companies to inform what we build for our organization. As Bruce Lee put it:', '', '> “Absorb what is useful, discard what is useless and add what is specifically your own”', '', 'Through scouring conference talks and blog posts from the past several years, I’ve documented ML platforms’ common components and capabilities at eleven large tech companies.', '', 'This post contains:', '', '* A high-level overview of common ML platform components', '', '* A table of tools used by each company', '* Observations about the components', '* The platform user experience', '* A summary of capabilities unique to certain companies', ''], subsections=[]), Section(title=Common ML platform Components, level=1, content=['', 'At a high level, five ML platform components stand out which are indicated by the green boxes in the diagram below.', '', '![[1_iHrlnI8XelORdRn9UslmOA.1.png]]', '![[1_iHrlnI8XelORdRn9UslmOA.png]]', '', 'Common components in an ML platform. Diagram by the author', '', 'Common components explained:', '', '* Feature store: A service that stores batch and streaming features and serves features for both offline and online use. A feature store usually supports low-latency serving, guarantees consistency between offline and online features, and allows both contribution and access to features across teams. If you want to learn more about feature stores, read [Feature Stores — A Hierarchy of Needs](https://eugeneyan.com/writing/feature-stores/) by Eugene Yan.', '', '* Workflow orchestration: Model training jobs are oftentimes represented as a directed acyclic graph (DAG) and need a tool that orchestrates the execution of tasks. DAGs may range from a simple two-step DAG of (model training) -> (model validation) to complex structures involving hyper-parameter tuning and multiple models. I won’t go into the model training pipeline as a component because typically, the platform handles orchestration, and w ...
#
# ---
# Всякое-разное - дневник.md
# Frontmatter: {'created': datetime.date(2023, 12, 21), 'aliases': None, 'tags': ['diary'], 'url': None}
# /Users/dvolk/repo/cobrain/vault/notes/Всякое-разное - дневник.md
# ['diary']
# Section(title=root, level=0, content=['---', 'created: 2023-12-21', 'aliases:', 'tags:', '- diary', 'url:', '---'], subsections=[Section(title=Всякое-разное - дневник, level=1, content=[], subsections=[Section(title=Контемп у Саши 2023-05-13, level=2, content=['![[2023-05-13 16.00.18.jpg|700]]![[2023-05-13 15.59.06.jpg|300]]', ''], subsections=[]), Section(title=Хайк по Мтацминде 2023-05-14, level=2, content=[], subsections=[])])])
#
# ---
# HSE.md
# Frontmatter: {'aliases': ['Higher School of Economics'], 'created': datetime.date(2022, 6, 14), 'modified': datetime.date(2022, 12, 1)}
# /Users/dvolk/repo/cobrain/vault/notes/HSE.md
# []
# Section(title=root, level=0, content=['---', 'aliases: [Higher School of Economics]', 'created: 2022-06-14', 'modified: 2022-12-01', '---', 'Москва'], subsections=[])
#
# ---
# HyperWallet больше с Россией не работает.md
# Frontmatter: {'created': datetime.date(2022, 6, 14), 'modified': datetime.date(2022, 12, 1)}
# /Users/dvolk/repo/cobrain/vault/notes/HyperWallet больше с Россией не работает.md
# []
# Section(title=root, level=0, content=['---', 'created: 2022-06-14', 'modified: 2022-12-01', '---', '2022-03-20', '', 'Письмо топталерам, работающим из [[РФ]]:', '> In light of recent events, I wanted to check in and share some additional information on payment options for [[Toptal]] talent based in [[РФ|Russia]]. If you are already in touch directly with our Talent Payments team, the information that has been shared directly with you will supersede what I am sharing below.As you may have been alerted to, effective March 22, 2022, Toptal’s default payment provider, [[Hyperwallet]], will no longer support [[РФ|Russia]] payouts. Based on current information, [[Toptal]]’s alternate payment provider, [[Payoneer]], is continuing to support bank transfers to non-sanctioned bank accounts. Please read [this document](https://docs.google.com/document/d/1efGCjdHfyFzKWEFAntXHOGSyDGf-4nN7SeMpmZjpJsw/edit) in full for additional details. According to your talent profile, you are actively working on an engagement and located within Russia, so we wanted to be sure to proactively share this information. When you have a moment, please let us know your current status.', '>', '> - **If you have relocated to another country**, please let us know immediately (including your new country). You’ll want to make sure you have updated your banking information, per the linked doc above, as well as your current city and country within your profile.', '> - **If you are planning to relocate or are in the process of relocating to another country**, please let us know (including your intended destination). This information may help our finance team resolve any payment issues more quickly.', '> - **If you plan to remain in Russia, please let us know, including if you currently use Hyperwallet or Payoneer and if you are requesting any specific support from our finance team, such as help creating a Payoneer account or requesting a direct wire transfer.**', '>', '> We are here to support you, although we will be transparent and say that most solutions will require that you work directly with our finance team. If you should have issues completing your engagement or require a short break while you relocate, please let us know and we would be happy to help coordinate where we can. Thanks.', '', '', '---', '', '', '[[HyperWallet]] больше с Россией не работает. Менять адрес резидентства на другую страну и перевыпускать', '', '[[РФ]]', '[[Война на Украине (2022-2024)]]', '[[Toptal]]', '', '34 replies', '', '---', '', '![](attach/E01HSMSV622-U02GZ62E8V9-f38355f6df4d-48.jpg)', '', '[Rustem Sahatov](https://app.slack.com/team/U02GZ62E8V9)\xa0\xa0[1 day ago](https://toptal.slack.com/archives/C041ZDVBE/p1646750743187239?thread_ts=1646749386.270199&cid=C041ZDVBE)', '', 'То есть, теперь даже с Тинькофф нельзя деньги с топтала получать или что?', '', '![](attach/E01HSMSV622-U11PNTJDS-11dcfefd92b6-48.jpg)', '', '[Dmitry Ryazantsev](https://app.slack.com/team/U11PNTJDS)\xa0\xa0[1 day ago](https://toptal.slack.com/archives/C041ZDVBE/p1646751104508399?thread_ts=1646749386.270199&cid=C041ZDVBE)', '', '[[Wise]] или [[Hyperwallet]] ? (edited)', '', '![](attach/E01HSMSV622-U02GZ62E8V9-f38355f6df4d-48
- эмоционально на уровне ребёнка', '- у ребёнка эмпатия ещё не развита', '- не умеет считывать, когда надо извиниться, а когда не надо', '- поэтому выучил, что лучше делать это всегда'], subsections=[]), Section(title=2024-04-30, level=3, content=['re [[Flat tyre with rented car - Surprice, Italy, 2024|Gomma a terra 2024-04-26]]', '- пытаюсь впрячься, хотя не должен', '- сомневаюсь в человеческих законах', '- нонсенс', '-', '', '- кто-то, кому удобно, чтобы за это отвечал я', '', '- поскольку исходит от родителей, это правда про правила мира', '(как в Грузии, - от полицейского)', '', '- а точно ли родительская фигура шарит в происходящем?', '', '- оттенок моей вины', '- кто-то не берёт на себя ответственность, и лишняя падает на меня', '- а я пытаюсь понять, как я должен был это предусмотреть?!', '', '- вина: я не проверил наличие запаски', '- я должен быть сверхчеловеком, который всё держит', '', '- мб это не тревога за ситуацию, а психика ещё разгоняется, чтобы выжать из себя в ситуации ещё больше', '', '- выдохнуть, попуститься, вернуться в рамки человеческих возможностей', '', '- в грузинской истории ничего extra не произошло, она просто сама рассосалась', '', ''], subsections=[]), Section(title=2024-04-17, level=3, content=['- общее/частное с Леной', '', 'варианты базового недоверия обещаниям Лены', '-', '- "меня обманывают"', '- устроено иначе, чем у меня, но как-то устроено', '', 'в детстве было много тревожной непоследовательности', '-', '', 'последние два месяца я как будто чаще бухчу про наши отношения, чем Лена', 'но у меня и объективно больше сложностей в Швейцарии', '- плюс отсутствие у меня других каналов общения', '', 'ощущение, что я имею право так чувствовать'], subsections=[]), Section(title=2024-04-11, level=3, content=['- Еду за правами в Рустави - см. [[2024-04-01#Diary]]'], subsections=[]), Section(title=2024-03-06, level=3, content=['- если мне не хочется делать задачу, на что она похожа?', '- обуза?', '- страшный монстр?', '- ...', '- сначала прийти в состояние, когда я благодарен Лене, и жизни, и себе - и я большой', '- потом подходить к куче задач'], subsections=[]), Section(title=2024-02-28, level=3, content=['- нужна "ёлка", на которую можно вешать "шарики", которые я добываю в жизни', '- и "в магазин не завезли подходящих ёлок"', ''], subsections=[]), Section(title=2023-12-01, level=3, content=['ночные [[Game|заигры]]', '- кот из дома - мыши в пляс', '', '- нет знакомства, нет контакта с собственной системой ограничений', '- "пора закругляться" - тонкое естественное чувство', '- что мне уже не так пиково интересно', '', '- не обрубать, запрещаяя', '- а переключать волну внимания на что-то ещ ...
#
# ---
# e5-small-v2.md
# Frontmatter: {'created': datetime.date(2024, 2, 28), 'aliases': [], 'tags': [], 'url': None}
# /Users/dvolk/repo/cobrain/vault/notes/e5-small-v2.md
# []
# Section(title=root, level=0, content=['---', 'created:  2024-02-28', 'aliases:  []', 'tags:     []', 'url:', '---'], subsections=[Section(title=e5-small-v2, level=1, content=['', '[[Choosing an Embedding Model]]', ''], subsections=[Section(title=, level=19, content=[], subsections=[])])])
#
# ---
# 🎦 Did JWST SOLVE The Mystery of Supermassive Black Hole Origins?.md
# Frontmatter: {'created': datetime.date(2024, 3, 1), 'aliases': None, 'tags': None, 'url': 'https://www.youtube.com/watch?v=hxcUy-cBVcI'}
# /Users/dvolk/repo/cobrain/vault/notes/🎦 Did JWST SOLVE The Mystery of Supermassive Black Hole Origins?.md
# None
# Section(title=root, level=0, content=['---', 'created: 2024-03-01', 'aliases:', 'tags:', 'url: https://www.youtube.com/watch?v=hxcUy-cBVcI', '---'], subsections=[Section(title=🎦 Did JWST SOLVE The Mystery of Supermassive Black Hole Origins?, level=1, content=['by [[PBS Space Time]]', '', '[[whisper.cpp]]:', "This is what we astronomers call a blob, or a smudge to use more technical language. It may not look like much from here, but what do you expect for something near the literal edge of the observable universe? If you were there when this light was emitted, you'd a) be at the beginning of time and b) be looking at an entire galaxy containing an enormous black hole at its heart. It's the most distant black hole we've semi-directly detected. That's cool enough on its own, but as an added bonus, this one smudge may have solved the mystery of the origin of the supermassive black holes in our modern universe. Introducing Abel 2744. It's a giant cluster of galaxies around 4 billion light years away, basically our backyard, cosmologically speaking. The most interesting thing about Abel 2744, at least for us today, isn't what's in this cluster itself, but what's behind it. The cluster lives in a vast halo of dark matter that warps space across its 4 million light year span. Light from distant objects traveling through the cluster is deflected and magnified. The cluster is a stupendous gravitational lens that enables us to see much further than our puny human-made telescopes would normally allow. That's why the Hubble Space Telescope studied Abel 2744 in detail, and why it was one of the early must-do's for the James Webb Space Telescope. And this is where our smudge got interesting. JWST observes deep into infrared wavelengths and showed that this object has eye-arc colours consistent with a galaxy whose normally visible light has been stretched out by the expanding universe, increasing or redshifting its wavelength by a factor of over 10. Higher redshift means larger distance, and a redshift of 10.1 in this case means this light has been traveling to us for around 13.2 billion years, coming to us from a time near the beginning of time, when the universe was less than 3.5% its current age. That earned our smudge the name UH-Z1 for Ultra High Redshift Galaxy Number 1, where the Z is the symbol for redshift. That's cool, but JWST has now found galaxies quite a bit more distant than this. The really exciting moment came when we pointed another orbiting satellite at this smudge. This is the image by the Chandra X-ray Telescope. It turns out there are a lot of X-rays coming from this little blob. Now, X-rays are much harder to bring to sharp focus, so the 4 pixels of the X-ray light aren't coming from across this spread out region, but rather from something inside that region. There's really only one known way for a galaxy to be blasting out X-rays at this level, and that's by harboring a quasar. To refresh your memory, a quasar is when a supermassive black hole, an SMBH, that lives in the center of every galaxy starts feeding. As matter swirls towards the black hole, it's superheated until it outshines the entire surrounding galaxy. And just before it reaches the black hole, conditions get so crazy that the space outside the black hole glows bright with high-energy X-rays. Based on the amount of X-ray light and the distance, we can estimate that the black hole must be 40 million times our sun's mass. That's 10 times the mass of the Milky Way's own SMBH. UHZ1 is the most distant quasar ever discovered, which makes it the earliest known quasar, and so the earliest black hole that we have evidence for. So with that out of the way, let's get to the good stuff. To understand why UHZ1 is so exciting, you have to understand one of the biggest debates in cosmology - the origin of supermassive black holes. Essentially every galaxy in the modern universe has at its core a black hole that's 100,000 to several billion times the mass of the sun. We  ...
#
# ---
# Медицина в Грузии.md
# Frontmatter: {'aliases': [], 'created': datetime.date(2023, 4, 20), 'modified': datetime.date(2023, 4, 20)}
# /Users/dvolk/repo/cobrain/vault/notes/Медицина в Грузии.md
# []
. И, соответственно, мы полетели в Таиланд и там ждали, когда Бали откроется, чтобы потом полететь на Бали. Чтобы у нас была такая двойная зимовка и в Таиланде, и на Бали. И, собственно, Бали открылся 14 февраля, я очень хорошо помню. Пока там он открылся, пока мы, в общем, очнулись, пока билеты стали доступны. Я помню, что числа типа 16-18 я начала уже искать билеты. Ближайшие классные билеты были на 24-е. А 4-го марта у меня уже были в Москве встречи и дела. И мне все говорят, Тань, ну ты типа сумасшедшая, нахрен тебе лететь на неделю на Бали. Ну типа, что за бред? А у меня была какая-то очень-очень сильная уверенность, что надо это сделать. Ну, как бы я до сих пор не понимаю, откуда это было. Потому что я в предыдущей своей зимовке на Бали не посетила вулкан. И весь год вообще не могла успокоиться от этой мысли. То есть я была там, жила там два месяца на Бали и так и не поднялась на вулкан. А тут это как бы такой моветон. Все поднимаются на вулканы. И я говорю, ребята, если я еще год буду думать про непокоренный вулкан, я просто охерею. Поэтому я полечу на Бали, это крюк, 4 часа 5 на самолете, поднимусь на вулкан и полечу в Москву. Типа, вот. И все говорили мне, что я сумасшедшая, но мне часто так говорят, у меня к этому толерантность.', '', 'Вот, соответственно, я купила эти билеты, не стала брать билеты в Москву, потому что тоже подумала, ну, может, не 4-го, может, 8-го полечу. У меня там эти встречи, в принципе, немножко были flexible. Но план был вот к 10 марта точно возвращаться в Москву, потому что у нас уже стояли  ...
#
# ---

# %%
vault = otools.Vault("/Users/dvolk/repo/cobrain/vault/").connect(attachments=False).gather()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 vault = otools.Vault("/Users/dvolk/repo/cobrain/vault/").connect(attachments=False).gather()
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/api.py:138, in Vault.__init__(self, dirpath, include_subdirs, include_root)
#     135 self._dirpath = dirpath
#     136 self._attachments = None  # connect()
# --> 138 self._md_file_index = self._get_md_relpaths_by_name(
#     139     include_subdirs=include_subdirs,
#     140     include_root=include_root)
#     141 self._canvas_file_index = self._get_canvas_relpaths_by_name(
#     142     include_subdirs=include_subdirs,
#     143     include_root=include_root)
#     145 self._is_connected = False
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/api.py:1115, in Vault._get_md_relpaths_by_name(self, **kwargs)
#    1114 def _get_md_relpaths_by_name(self, **kwargs) -> dict[str, Path]:
# -> 1115     return self.__get_relpaths_by_name(extension='md',
#    1116                                        **kwargs)
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/api.py:1082, in Vault.__get_relpaths_by_name(self, extension, **kwargs)
#    1079 # get note names (for k) and relpaths (for v):
#    1080 # keep or remove ext, based on how the file refs appear in wikilinks:
#    1081 if extension == 'md':
# -> 1082     relpaths_list = self._get_md_relpaths(
#    1083         **kwargs)
#    1084     # remove .md ext:
#    1085     all_file_names_list = [f.stem for f in relpaths_list]
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/api.py:1059, in Vault._get_md_relpaths(self, **kwargs)
#    1052 def _get_md_relpaths(self, **kwargs) -> list[Path]:
#    1053     """Return list of md filepaths *relative* to the directory instantiated
#    1054     for the class.
#    1055
#    1056     Returns:
#    1057         list
#    1058     """
# -> 1059     return get_md_relpaths_matching_subdirs(self._dirpath, **kwargs)
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/md_utils.py:70, in get_md_relpaths_matching_subdirs(dir_path, include_subdirs, include_root)
#      40 def get_md_relpaths_matching_subdirs(dir_path: Path, *,
#      41                                      include_subdirs: list = None,
#      42                                      include_root: bool = True) -> list[Path]:
#      43     """Get list of relative paths for markdown files in a given directory,
#      44     filtered to include specified subdirectories (with include_subdirs
#      45     kwarg).  The default arguments align with get_md_relpaths_from_dir
#    (...)
#      68         list of Path objects
#      69     """
# ---> 70     return get_relpaths_matching_subdirs(
#      71         dir_path,
#      72         extension='md',
#      73         include_subdirs=include_subdirs,
#      74         include_root=include_root)
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/_io.py:68, in get_relpaths_matching_subdirs(dir_path, extension, include_subdirs, include_root)
#      64     include_subdirs_final = [str(Path(i).as_posix())
#      65                              for i in include_subdirs]
#      67 if not include_subdirs and include_root:
# ---> 68     return get_relpaths_from_dir(dir_path,
#      69                                  extension=extension)
#      70 elif not include_subdirs and not include_root:
#      71     return [i for i in get_relpaths_from_dir(dir_path,
#      72                                              extension=extension)
#      73             if str(i.parent.as_posix()) != '.']
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/_io.py:21, in get_relpaths_from_dir(dir_path, extension)
#       6 def get_relpaths_from_dir(dir_path: Path, *, extension: str) -> list[Path]:
#       7     """Get list of relative paths for {extension} files in a given directory,
#       8     including any subdirectories.
#       9
#    (...)
#      19         list of Path objects
#      20     """
# ---> 21     relpaths_list = [Path(p).relative_to(dir_path)
#      22                      for p in glob(f"{dir_path}/**/*.{extension}",
#      23                      recursive=True)]
#      24     return relpaths_list
#
# File ~/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/_io.py:21, in <listcomp>(.0)
#       6 def get_relpaths_from_dir(dir_path: Path, *, extension: str) -> list[Path]:
#       7     """Get list of relative paths for {extension} files in a given directory,
#       8     including any subdirectories.
#       9
#    (...)
#      19         list of Path objects
#      20     """
# ---> 21     relpaths_list = [Path(p).relative_to(dir_path)
#      22                      for p in glob(f"{dir_path}/**/*.{extension}",
#      23                      recursive=True)]
#      24     return relpaths_list
#
# File ~/mambaforge/lib/python3.10/pathlib.py:809, in PurePath.relative_to(self, *other)
#     807 else:
#     808     abs_parts = parts
# --> 809 to_drv, to_root, to_parts = self._parse_args(other)
#     810 if to_root:
#     811     to_abs_parts = [to_drv, to_root] + to_parts[1:]
#
# File ~/mambaforge/lib/python3.10/pathlib.py:587, in PurePath._parse_args(cls, args)
#     582         else:
#     583             raise TypeError(
#     584                 "argument should be a str object or an os.PathLike "
#     585                 "object returning str, not %r"
#     586                 % type(a))
# --> 587 return cls._flavour.parse_parts(parts)
#
# File ~/mambaforge/lib/python3.10/pathlib.py:71, in _Flavour.parse_parts(self, parts)
#      69     for x in reversed(rel.split(sep)):
#      70         if x and x != '.':
# ---> 71             parsed.append(sys.intern(x))
#      72 else:
#      73     if rel and rel != '.':
#
# KeyboardInterrupt:

# %%
vault.get_all_file_metadata()
# Out:
# /Users/dvolk/repo/spellstone/.venv/lib/python3.10/site-packages/obsidiantools/api.py:1343: UserWarning: Only notes (md files) were used to build the graph.  Set attachments=True in the connect method to show all file metadata.
#   warnings.warn('Only notes (md files) were used to build the graph.  Set attachments=True in the connect method to show all file metadata.')
# Empty DataFrame
# Columns: [rel_filepath, abs_filepath, file_exists, n_backlinks, n_wikilinks, n_tags, n_embedded_files, modified_time, graph_category]
# Index: []

# %%
vault.md_file_index
# Out:
# {}
